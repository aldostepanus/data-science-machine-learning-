# %%
from __future__ import print_function
 
import logging
import os.path
import sys
 
from gensim.corpora import WikiCorpus
 
program = os.path.basename(sys.argv[0])
logger = logging.getLogger(program)
 
logging.basicConfig(format='%(asctime)s: %(levelname)s: %(message)s')
logging.root.setLevel(level=logging.INFO)
logger.info("running %s" % ' '.join(sys.argv))
 
namaFileInput = "/content/drive/My Drive/Colab Notebooks/idwiki-latest-pages-articles.xml.bz2"
namaFileOutput = "/content/drive/My Drive/Colab Notebooks/wiki.id.case2.text"
 
space = " "
i = 0
 
output = open(namaFileOutput, 'w')

wiki = WikiCorpus(namaFileInput, lemmatize=False, dictionary={}, lower=True)
for text in wiki.get_texts():
    output.write(' '.join(text) + '\n')
    i = i + 1
    if i % 10000 == 0:
        logger.info("Saved " + str(i) + " articles")
 
output.close()
logger.info("Finished Saved " + str(i) + " articles")
# Out:
# 2020-09-29 11:33:55,641: INFO: running /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-a01c34ea-cfc4-4976-8d5d-f601cd22c83e.json
# 2020-09-29 11:35:16,282: INFO: Saved 10000 articles
# 2020-09-29 11:36:11,343: INFO: Saved 20000 articles
# 2020-09-29 11:37:00,117: INFO: Saved 30000 articles
# 2020-09-29 11:37:43,575: INFO: Saved 40000 articles
# 2020-09-29 11:38:27,538: INFO: Saved 50000 articles
# 2020-09-29 11:39:06,730: INFO: Saved 60000 articles
# 2020-09-29 11:39:48,830: INFO: Saved 70000 articles
# 2020-09-29 11:40:37,670: INFO: Saved 80000 articles
# 2020-09-29 11:41:23,720: INFO: Saved 90000 articles
# 2020-09-29 11:42:10,103: INFO: Saved 100000 articles
# 2020-09-29 11:42:52,559: INFO: Saved 110000 articles
# 2020-09-29 11:43:28,720: INFO: Saved 120000 articles
# 2020-09-29 11:44:15,753: INFO: Saved 130000 articles
# 2020-09-29 11:44:58,176: INFO: Saved 140000 articles
# ...

# %%
import multiprocessing
import logging
import os.path
import sys
import multiprocessing
from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence
 
program = os.path.basename(sys.argv[0])
logger = logging.getLogger(program)
 
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s')
logging.root.setLevel(level=logging.INFO)
logger.info("running %s" % ' '.join(sys.argv))
 
namaFileInput = "/content/drive/My Drive/Colab Notebooks/wiki.id.case2.text"
namaFileOutput = "/content/drive/My Drive/Colab Notebooks/w2vec_wiki_id_300_2"
 
model = Word2Vec(LineSentence(namaFileInput), size=300, window=5, min_count=5, workers=multiprocessing.cpu_count())
 
# trim unneeded model memory = use (much) less RAM
model.init_sims(replace=True)
model.save(namaFileOutput)
# Out:
# 2020-09-29 11:57:49,503: INFO: running /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-a01c34ea-cfc4-4976-8d5d-f601cd22c83e.json
# 2020-09-29 11:57:49,506: INFO: collecting all words and their counts
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:254: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 2020-09-29 11:57:49,573: INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-09-29 11:57:52,732: INFO: PROGRESS: at sentence #10000, processed 8991186 words, keeping 276714 word types
# 2020-09-29 11:57:54,802: INFO: PROGRESS: at sentence #20000, processed 14453595 words, keeping 383846 word types
# ...
